# %%
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
mobile_data = './data/2023-12-18T14.54.21.csv'

# %%
df = pd.read_csv(mobile_data, header=1,  delimiter=';',decimal=',', low_memory=False)
print(df.shape)
print(df.columns)
# Out:
# (62203, 23)
# Index(['time', 'gFx', 'gFy', 'gFz', 'ax', 'ay', 'az', 'wx', 'wy', 'wz', 'p',
#        'Bx', 'By', 'Bz', 'I', 'Azimuth', 'Pitch', 'Roll', 'Gain', 'Latitude',
#        'Longitude', 'Speed (m/s)', ',,,,,,,,,,,,,,,,,,,,,,'],
#       dtype='object')

# %%
df
# Out:
#              time      gFx     gFy     gFz      ax       ay       az       wx  \
# 0        0.082912  −0,0794  0.1006  0.9986  0,0000   0,0000   0,0000   0,0000
# 1        0.084798  −0,0794  0.1006  0.9986  0,0000   0,0000   0,0000   0,0000
# 2        0.086152  −0,0794  0.1006  0.9986  0,0000   0,0000   0,0000   0,0000
# 3        0.091710  −0,0794  0.1006  0.9986  0,0000   0,0000   0,0000  −0,0194
# 4        0.145038  −0,0794  0.1006  0.9986  0,0000   0,0000   0,0000  −0,0194
# ...           ...      ...     ...     ...     ...      ...      ...      ...
# 62198  613.749605  −0,0820  0.1251  0.9981  0,0601  −0,0523  −0,0281   0,0541
# 62199  613.750084  −0,0820  0.1251  0.9981  0,0601  −0,0523  −0,0281   0,0541
# 62200  613.750724  −0,0820  0.1251  0.9981  0,0601  −0,0523  −0,0281  −0,0399
# 62201  613.784349  −0,0820  0.1251  0.9981  0,0601  −0,0523  −0,0281  −0,0399
# 62202  613.789115  −0,0820  0.1251  0.9981  0,0601  −0,0523  −0,0281  −0,0399
#
#             wy       wz  ...        Bz      I   Azimuth    Pitch     Roll  \
# 0       0,0000   0,0000  ...    0,0000    0.0    0.0000   0,0000   0,0000
# 1       0,0000   0,0000  ...    0,0000  560.0    0.0000   0,0000   0,0000
# 2       0,0000   0,0000  ...  −17,7188  560.0    0.0000   0,0000   0,0000
# 3       0,0050   0,0316  ...  −17,7188  560.0    0.0000   0,0000   0,0000
# 4       0,0050   0,0316  ...  −17,6250  560.0    0.0000   0,0000   0,0000
# ...        ...      ...  ...       ...    ...       ...      ...      ...
# 62198   0,0287  −0,0298  ...  −18,3563  553.0  346.2056  −5,8006  −4,3374
# 62199   0,0287  −0,0298  ...  −18,3563  553.0  346.2566  −5,9893  −4,4538
# 62200  −0,0115   0,0266  ...  −18,3563  553.0  346.2566  −5,9893  −4,4538
# 62201  −0,0115   0,0266  ...  −18,3563  553.0  346.2566  −5,9893  −4,4538
# 62202  −0,0115   0,0266  ...  −18,2812  553.0  346.2566  −5,9893  −4,4538
#
#             Gain   Latitude  Longitude Speed (m/s)  ,,,,,,,,,,,,,,,,,,,,,,
# 0             −∞   0.000000   0.000000         0.0                       ,
# 1             −∞  59.944138  10.713074         0.0                       ,
# 2             −∞  59.944138  10.713074         0.0                       ,
# 3             −∞  59.944138  10.713074         0.0                       ,
# 4             −∞  59.944138  10.713074         0.0                       ,
# ...          ...        ...        ...         ...                     ...
# 62198  −291,2142  59.944221  10.713059         0.0                     NaN
# 62199  −291,2142  59.944221  10.713059         0.0                     NaN
# 62200  −291,2142  59.944221  10.713059         0.0                     NaN
# 62201  −291,2142  59.944221  10.713059         0.0                     NaN
# 62202  −291,2142  59.944221  10.713059         0.0                     NaN
#
# [62203 rows x 23 columns]

# %%
# Reading time, light intensity and gain from the csv


# Read the CSV file into a Pandas DataFrame
df = pd.read_csv(mobile_data, header=1,  delimiter=';',decimal=',', low_memory=False)

# Specify the column names you want to display
selected_columns = ['time', 'I', 'Gain']

# Select and display the specified columns
df_selected = df[selected_columns]
print(df_selected)
# Out:
#              time      I       Gain
# 0        0.082912    0.0         −∞
# 1        0.084798  560.0         −∞
# 2        0.086152  560.0         −∞
# 3        0.091710  560.0         −∞
# 4        0.145038  560.0         −∞
# ...           ...    ...        ...
# 62198  613.749605  553.0  −291,2142
# 62199  613.750084  553.0  −291,2142
# 62200  613.750724  553.0  −291,2142
# 62201  613.784349  553.0  −291,2142
# 62202  613.789115  553.0  −291,2142
#
# [62203 rows x 3 columns]

# %%
df_selected
# Out:
#              time      I       Gain
# 0        0.082912    0.0         −∞
# 1        0.084798  560.0         −∞
# 2        0.086152  560.0         −∞
# 3        0.091710  560.0         −∞
# 4        0.145038  560.0         −∞
# ...           ...    ...        ...
# 62198  613.749605  553.0  −291,2142
# 62199  613.750084  553.0  −291,2142
# 62200  613.750724  553.0  −291,2142
# 62201  613.784349  553.0  −291,2142
# 62202  613.789115  553.0  −291,2142
#
# [62203 rows x 3 columns]

# %%
df_selected.dtypes
# Out:
# time    float64
# I       float64
# Gain     object
# dtype: object

# %%
# Replacing n-dash with hyphen
df_selected=df_selected.replace(to_replace='−', value='-',regex=True)
# Replacing comma with dot
df_selected=df_selected.replace(to_replace=',', value='.',regex=True)
# Replacing NAN with zeros
df_selected=df_selected.replace(to_replace='∞', value='0',regex=True)

df_selected
# Out:
#              time      I       Gain
# 0        0.082912    0.0         -0
# 1        0.084798  560.0         -0
# 2        0.086152  560.0         -0
# 3        0.091710  560.0         -0
# 4        0.145038  560.0         -0
# ...           ...    ...        ...
# 62198  613.749605  553.0  -291.2142
# 62199  613.750084  553.0  -291.2142
# 62200  613.750724  553.0  -291.2142
# 62201  613.784349  553.0  -291.2142
# 62202  613.789115  553.0  -291.2142
#
# [62203 rows x 3 columns]

# %%
# Now that the data should have been formatted correctly, we can change to float64
df_selected=df_selected.astype(float)
df_selected.dtypes
# Out:
# time    float64
# I       float64
# Gain    float64
# dtype: object

# %%
#Calculating the sampling rate

total_duration = df_selected['time'].max() #- df_selected['time'].min()
num_of_data_points = len(df_selected)

sr = num_of_data_points / total_duration

print(total_duration)
sr
# Out:
# 613.789115
# 101.34262481992695

# %%
#The sampling rate is higher than necessary.
#Therefore, we remove rows with no change in data as they are redundant.
#We use Gain here because it fluctuates more than light intensity, so we end up losing the least data.

df_selected = df_selected.drop_duplicates(subset=['Gain'], keep='first')
df_selected
# Out:
#              time      I      Gain
# 0        0.082912    0.0   -0.0000
# 46       0.549562  561.0   68.7030
# 78       0.838104  560.0   85.6273
# 109      1.151676  562.0   88.0147
# 140      1.437483  563.0   89.4174
# ...           ...    ...       ...
# 62095  600.162879  607.0   51.0142
# 62108  612.862913  554.0 -267.3378
# 62118  613.005711  554.0 -275.2966
# 62151  613.304304  553.0 -283.2554
# 62181  613.606715  554.0 -291.2142
#
# [1963 rows x 3 columns]

# %%
#Calculating the new sampling rate

total_duration = df_selected['time'].max() #- df_selected['time'].min()
num_of_data_points = len(df_selected)

sr = num_of_data_points / total_duration

print(total_duration)
sr
# Out:
# 613.606715
# 3.1991175324735486

# %%
fig = plt.figure(figsize=(14,2))
plt.plot(df_selected);

# %%
fig, ax = plt.subplots(figsize=(14,2))
plt.plot(df_selected.I);

# %%
fig, ax = plt.subplots(figsize=(14,2))
plt.xlim(11000, 16000)
plt.plot(df_selected.I);

# %%
# Function to process frames and extract RGB values and brightness
def process_video(video_path, num_frames):
    video = cv2.VideoCapture('./data/light_intensity/ricoh.mp4')
    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    frames_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
    
    rgb_values = []
    brightness_values = []
    
    for idx in frames_indices:
        video.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = video.read()
        if not ret:
            continue
        
        # Convert frame to grayscale for brightness calculation
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # Calculate average brightness
        brightness = np.mean(gray_frame)
        brightness_values.append(brightness)
        
        # Calculate RGB values
        r, g, b = frame[:,:,0], frame[:,:,1], frame[:,:,2]
        avg_r = np.mean(r)
        avg_g = np.mean(g)
        avg_b = np.mean(b)
        rgb_values.append((avg_r, avg_g, avg_b))
    
    video.release()
    
    return rgb_values, brightness_values

# Function to plot RGB and brightness graphs on the same plot
def plot_graphs(rgb_values, brightness_values):
    num_frames = len(rgb_values)
    indices = np.arange(num_frames)
    
    # Plot RGB values and brightness on the same plot
    plt.figure(figsize=(12, 6))
    
    # Plot RGB values
    plt.plot(indices, np.array(rgb_values)[:,0], color='red', label='Red')
    plt.plot(indices, np.array(rgb_values)[:,1], color='green', label='Green')
    plt.plot(indices, np.array(rgb_values)[:,2], color='blue', label='Blue')
    
    # Plot brightness
    plt.plot(indices, brightness_values, color='black', label='Brightness')
    
    plt.title('RGB and Brightness Values')
    plt.xlabel('Frame Index')
    plt.ylabel('Intensity')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
video_path = './data/light_intensity/ricoh.mp4'
num_frames = 100  # Number of frames to process

rgb_values, brightness_values = process_video(video_path, num_frames)
plot_graphs(rgb_values, brightness_values)

# %%
np.save("ricoh_rgb.npy", np.array(rgb_values))
np.save("ricoh_brightness.npy", np.array(brightness_values))

# %%
def process_video(video_path, num_frames):
    video = cv2.VideoCapture('./data/light_intensity/garmin.mp4')
    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    frames_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
    
    rgb_values = []
    brightness_values = []
    
    for idx in frames_indices:
        video.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = video.read()
        if not ret:
            continue
        
        # Convert frame to grayscale for brightness calculation
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # Calculate average brightness
        brightness = np.mean(gray_frame)
        brightness_values.append(brightness)
        
        # Calculate RGB values
        r, g, b = frame[:,:,0], frame[:,:,1], frame[:,:,2]
        avg_r = np.mean(r)
        avg_g = np.mean(g)
        avg_b = np.mean(b)
        rgb_values.append((avg_r, avg_g, avg_b))
    
    video.release()
    
    return rgb_values, brightness_values

def plot_graphs(rgb_values, brightness_values):
    num_frames = len(rgb_values)
    indices = np.arange(num_frames)
    
    # Plot RGB values and brightness on the same plot
    plt.figure(figsize=(12, 6))
    
    # Plot RGB values
    plt.plot(indices, np.array(rgb_values)[:,0], color='red', label='Red')
    plt.plot(indices, np.array(rgb_values)[:,1], color='green', label='Green')
    plt.plot(indices, np.array(rgb_values)[:,2], color='blue', label='Blue')
    
    # Plot brightness
    plt.plot(indices, brightness_values, color='black', label='Brightness')
    
    plt.title('RGB and Brightness Values')
    plt.xlabel('Frame Index')
    plt.ylabel('Intensity')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
video_path = './data/light_intensity/garmin.mp4'
num_frames = 100  # Number of frames to process

rgb_values, brightness_values = process_video(video_path, num_frames)
plot_graphs(rgb_values, brightness_values)

# %%
np.save("garmin_rgb.npy", np.array(rgb_values))
np.save("garmin_brightness.npy", np.array(brightness_values))

# %%
def process_video(video_path, num_frames):
    video = cv2.VideoCapture('./data/light_intensity/gopro.mp4')
    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    frames_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
    
    rgb_values = []
    brightness_values = []
    
    for idx in frames_indices:
        video.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = video.read()
        if not ret:
            continue
        
        # Convert frame to grayscale for brightness calculation
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # Calculate average brightness
        brightness = np.mean(gray_frame)
        brightness_values.append(brightness)
        
        # Calculate RGB values
        r, g, b = frame[:,:,0], frame[:,:,1], frame[:,:,2]
        avg_r = np.mean(r)
        avg_g = np.mean(g)
        avg_b = np.mean(b)
        rgb_values.append((avg_r, avg_g, avg_b))
    
    video.release()
    
    return rgb_values, brightness_values

def plot_graphs(rgb_values, brightness_values):
    num_frames = len(rgb_values)
    indices = np.arange(num_frames)
    
    # Plot RGB values and brightness on the same plot
    plt.figure(figsize=(12, 6))
    
    # Plot RGB values
    plt.plot(indices, np.array(rgb_values)[:,0], color='red', label='Red')
    plt.plot(indices, np.array(rgb_values)[:,1], color='green', label='Green')
    plt.plot(indices, np.array(rgb_values)[:,2], color='blue', label='Blue')
    
    # Plot brightness
    plt.plot(indices, brightness_values, color='black', label='Brightness')
    
    plt.title('RGB and Brightness Values')
    plt.xlabel('Frame Index')
    plt.ylabel('Intensity')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
video_path = './data/light_intensity/gopro.mp4'
num_frames = 100  # Number of frames to process

rgb_values, brightness_values = process_video(video_path, num_frames)
plot_graphs(rgb_values, brightness_values)

# %%
np.save("gopro_rgb.npy", np.array(rgb_values))
np.save("gopro_brightness.npy", np.array(brightness_values))

# %%
def process_video(video_path, num_frames):
    video = cv2.VideoCapture('./data/light_intensity/insta.mp4')
    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    frames_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
    
    rgb_values = []
    brightness_values = []
    
    for idx in frames_indices:
        video.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = video.read()
        if not ret:
            continue
        
        # Convert frame to grayscale for brightness calculation
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # Calculate average brightness
        brightness = np.mean(gray_frame)
        brightness_values.append(brightness)
        
        # Calculate RGB values
        r, g, b = frame[:,:,0], frame[:,:,1], frame[:,:,2]
        avg_r = np.mean(r)
        avg_g = np.mean(g)
        avg_b = np.mean(b)
        rgb_values.append((avg_r, avg_g, avg_b))
    
    video.release()
    
    return rgb_values, brightness_values

def plot_graphs(rgb_values, brightness_values):
    num_frames = len(rgb_values)
    indices = np.arange(num_frames)
    
    # Plot RGB values and brightness on the same plot
    plt.figure(figsize=(12, 6))
    
    # Plot RGB values
    plt.plot(indices, np.array(rgb_values)[:,0], color='red', label='Red')
    plt.plot(indices, np.array(rgb_values)[:,1], color='green', label='Green')
    plt.plot(indices, np.array(rgb_values)[:,2], color='blue', label='Blue')
    
    # Plot brightness
    plt.plot(indices, brightness_values, color='black', label='Brightness')
    
    plt.title('RGB and Brightness Values')
    plt.xlabel('Frame Index')
    plt.ylabel('Intensity')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
video_path = './data/light_intensity/insta.mp4'
num_frames = 100  # Number of frames to process

rgb_values, brightness_values = process_video(video_path, num_frames)
plot_graphs(rgb_values, brightness_values)

# %%
np.save("insta_rgb.npy", np.array(rgb_values))
np.save("insta_brightness.npy", np.array(brightness_values))
